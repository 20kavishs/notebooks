# %% [markdown]
# ## PHYS280: Homework 7
# ### Kavish Senthilkumar
#
#
#
#
# ### Your Turn 11C
#
# We write the abbrevations $U_t$ for the event of being unbound at time (or time interval) $t$ and $B_t$ for being unbound at time (or time interval) $t$
#
#
# (11.2) remains the same.
# $$P(B_{\Delta t}| B_{0}) = 1-(\Delta t) \beta_{\text{off}}$$
#
#
# We square $(P(\text{in the target}| U)$ in Equation 11.3, as there are 2 repressors acting.
# $$(11.3) \,\,\, P(B_{\Delta t}| \text{U but in target at } t=0)(P(\text{in the target}| \text{U})^2=(\kappa \Delta t ){(\frac{v}{V})}^2$$
#
# Using this in (11.4), we set $k_{on} = \kappa v$ and $c=\frac{2}{V}$ because of two repressors, so
#
# $$P(B_{\Delta t}| B_0) = k_{on} \Delta t \frac{v}{V^2}$$
#
# $$P(B_{\Delta t}| B_0) = k_{on} \Delta t \frac{vc^2}{4}$$
#
# Using (11.6), we expand $P(B_{\Delta t})$ in the same fashion.
#
# $$P(B_{\Delta t}) = P(U_{\Delta t}| U_0) P(U_0) + P(B_{\Delta t}| B_0) P(B_0)$$
# $$P(B_{\Delta t})= (k_{on} \Delta t \frac{vc^2}{4}) (1-P(B_0)) + (1-(\Delta t) \beta_{\text{off}}) P(B_0)$$
#
# Using equation (11.7) (specifically, the cancelling of time based terms because of steady state equilibrium),
#
# $$0= (\frac{k_{on}vc^2}{4}) (1-P(B)) - \beta_{\text{off}} P(B)$$
#
# Using equation (11.8), we solve for $P(B)$.
#
# $$0= (\frac{k_{on}vc^2}{4}) - \frac{k_{on}vc^2}{4} P(B) - \beta_{\text{off}} P(B)$$
# $$(\frac{k_{on}vc^2}{4}+\beta_{\text{off}}) P(B) = (\frac{k_{on}vc^2}{4})$$
# $$ P(B) = \frac{{k_{on}vc^2}}{{k_{on}vc^2}+4\beta_{\text{off}}}$$
#
# Using equation (11.8), we solve for $P(U)$ by finding the complement.
#
# $$P(U) = 1-P(B)$$
#
# $$P(U) = \frac{{k_{on}vc^2}+4\beta_{\text{off}}-{k_{on}vc^2}}{{k_{on}vc^2}+4\beta_{\text{off}}}$$
#
# $$P(U) = \frac{4\beta_{\text{off}}}{{k_{on}vc^2}+4\beta_{\text{off}}} = \frac{1}{1+\frac{{k_{on}vc^2}}{4\beta_{\text{off}}}}$$
#
# Looking at (11.10), we create the dimensionless concentration variable ${\bar{c}}^2 = (\frac{c}{K_d})^2$. We set this variable to $\frac{{k_{on}vc^2}}{4\beta_{\text{off}}}$ to solve for $K_d$.
#
# $${\bar{c}}^2 = (\frac{c}{K_d})^2=\frac{{k_{on}vc^2}}{4\beta_{\text{off}}}$$
#
# $${K_d}=2\sqrt{\frac{\beta_{\text{off}}c^2}{{k_{on}vc^2}}}=2\sqrt{\frac{\beta_{\text{off}}}{{k_{on}v}}}$$
#
# Thus, using $K_d=2\sqrt{\frac{\beta_{\text{off}}}{{k_{on}v}}}$ and $\bar{c}=\frac{c}{K_d}$, we get the final equation
# $$P(U)=\frac{1}{1+\bar{c}^2}$$
#
# ### Cooperative autoregulation
#
# #### a
#
# Writing (11.6) but with $f(c)$ using $n>1$,
#
# $$\frac{dc}{dt} = \frac{f(c)}{V}-\frac{c}{\tau_{tot}} = \frac{\Gamma/V}{1+(c/K_d)^n}-\frac{c}{\tau_{tot}}$$
#
# Using the change of variables $y=c^{n+1}$ and assuming $c >> K_d$ so we can neglect the 1,
#
# $$\frac{dy}{dt} = (n+1) (c^{n}) \frac{dc}{dt} = (n+1)(c^n)(\frac{\Gamma/V}{(c/K_d)^n}-\frac{c}{\tau_{tot}})$$
# $$\frac{dy}{dt}  = (n+1)(\frac{\Gamma(K_d)^n}{V}-\frac{y}{\tau_{tot}})$$
#
#
# Following the derviation after (11.18), we model using the birth death process with the steady state $y_* = \frac{\Gamma (K_d)^n \tau_{tot}}{V}$
#
# $$\frac{d{y-y_*}}{dt} = \frac{-n-1}{\tau_{tot}} (y-y_*)$$
# $$y-y_* = Ae^{\frac{-n-1}{\tau_{tot}}t} $$
#
# As in the book derivation, we choose $A=\frac{-\tau_{tot}(K_D)^n \Gamma}{V}$ to satisfy initial requirements and substitute $y=c^{n+1}$. Then,
#
#
# $$c^{n+1} -y_* = Ae^{\frac{-n-1}{\tau_{tot}}t} $$
#
#
# $$c^{n+1} = y_*(1-e^{\frac{-n-1}{\tau_{tot}}t})$$
#
# $$c = (y_*)^{(n+1)^{-1}}(1-e^{\frac{-n-1}{\tau_{tot}}t})^{(n+1)^{-1}}$$
#
#
# $$\frac{c}{c_*} = (1-e^{\frac{-n-1}{\tau_{tot}}t})^{(n+1)^{-1}}$$
#
#
# #### b
#
# When $t >> \tau_{Tot}$, $\frac{t}{\tau_{Tot}} \rightarrow t$, so we have
#
# $$\frac{c}{c_*} = (1-e^{t(-n-1)})^{(n+1)^{-1}}$$
#
# Then, at late times, because $n > 1$, $t(-n-1) \rightarrow -\infty$, so $e^{t(-n-1)} \rightarrow 0$. Then, at late times, $\frac{c}{c_*} = (1-0)$ and $\boxed{c_* = c}$.
#
#
#
# ### Exact solution
#
# #### a.
#
# First, we must find an equation for the solution as a function of $\bar{t}$. Getting rid of the negative roots in the exact solutions and seeing $x_+ = \frac{-1+\sqrt{1+4S}}{2}$ we have
#
# $$P=\frac{1+x_+}{x_+} = \frac{1+\frac{-1+\sqrt{1+4S}}{2}}{\frac{-1+\sqrt{1+4S}}{2}} = \frac{{1+\sqrt{1+4S}}}{{-1+\sqrt{1+4S}}}$$
#
# Seeing that $\bar{t} = -P ln(1-\bar{c}/x)$, we have
#
# $$e^{\frac{-\bar{t}}{P}} = 1-\bar{c}/x$$
#
# $$\bar{c}/x = \bar{c}/c_*= 1-e^{\frac{-\bar{t}}{P}}$$
#
# The left hand side is our solution, and the right hand side is what we will graph in terms of $\bar{t}$, noting $P=\frac{{1+\sqrt{1+4S}}}{{-1+\sqrt{1+4S}}}$ from above.

# %%
# %matplotlib notebook
import matplotlib
from matplotlib import pyplot as plt
import numpy as np
from numpy.random import random as rng


matplotlib.rc('text', usetex = True)

#choose S values and tbar range
S=[10, 100, 1000, 10000]
tbar = np.linspace(0,3,num=2000)

#calculate exact solution value and plot
for i in S:
    P=(1+np.sqrt(1+4*i)) / (-1 + np.sqrt(1+4*i))
    val=1-np.exp(-tbar/P)
    plt.scatter(tbar, val, label="S = " + str(i), s=1)

#calculate approx solution and superimpose plot
approx = np.sqrt(1-np.exp(-2*tbar))
plt.scatter(tbar, approx, color="gray", label = "Approx", s=1)


#plotting specifics
plt.xlabel('$\overline{t}$')
plt.ylabel('$c/c_*$')
plt.legend(markerscale=4)
plt.title("Exact. Soln. For Various S Values Superimposed on Approx. Solution")
plt.show()

#import experimental data
cyan_data = np.loadtxt("https://raw.githubusercontent.com/dr-kinder/pmls-data/master/14autoregulation/regulatedCyan.csv", delimiter=",")
purple_data = np.loadtxt("https://raw.githubusercontent.com/dr-kinder/pmls-data/master/14autoregulation/regulatedPurple.csv", delimiter=",")
red_data = np.loadtxt("https://raw.githubusercontent.com/dr-kinder/pmls-data/master/14autoregulation/regulatedRed.csv", delimiter=",")
unreg_data = np.loadtxt("https://raw.githubusercontent.com/dr-kinder/pmls-data/master/14autoregulation/unregulated.csv", delimiter=",")

#plot experimental data
plt.figure()
plt.scatter(cyan_data[:,0], cyan_data[:,1], color="cyan", label = "Cyan Experimental", s=1)
plt.scatter(purple_data[:,0], purple_data[:,1], color="purple", label = "Purple Experimental", s=1)
plt.scatter(red_data[:,0], red_data[:,1], color="red", label = "Red Experimental", s=1)
plt.scatter(unreg_data[:,0], unreg_data[:,1], color="black", label = "Unreg. Experimental", s=1)

#plot approx solution
plt.scatter(tbar, approx_y, color="gray", label = "Approx. Solution", s=1)

#Choose highest S and plot that as exact solution
S=10000
P = (1+np.sqrt(1+4*S)) / (-1 + np.sqrt(1+4*S))

actual = 1-np.exp(-tbar/P)
plt.scatter(tbar, actual, color="green", label = "Exact Solution", s=1)
plt.xlabel("$\overline{t}$")
plt.ylabel("$c/c_*$")
plt.title("Exact and Approx. Solutions Superimposed on Experimental Data")
plt.legend(markerscale=4)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# As $S \rightarrow \infty$, the exact solutions increase for middle values of $\bar{t}$ and converge (for an estimate, see when $S=10000$). The exact solutions, for increasing $S$, no longer get closer to the approximate solution after converging (i.e. as $S \rightarrow \infty$, the exact solutions converge to a curve and do not get any closer to the approximation).
#
# We see the approximate solution is very close to the exact solution for very small and very large values of $\bar{t}$ but especially poor for $\bar{t}$ values in the middle of the range.
#
# We look at plot with experimental data. The unregulated experimental data aligns closely with the exact solution for a lower S. The remaining experimental data curves follow the approximate solution well up to about $\bar{t} \approx 0.5$. We also observe oscillations for the cyan, purple, and red solutions our approximate or exact solutions do not account for. Like we talked about in class, this could indicate our model was not sufficiently complex to account for this phenomena.
#
#
# ### Credit
#
# Credit to Will and Jas for help on derivations for 1 and 2, Sagar for code help (Stack Overflow for some formatting changes too)
